# %%
marks = {
    "Aarav": 78,
    "Diya": 92,
    "Kabir": 65,
    "Meera": 88,
    "Rohan": 72
}
print(marks["Meera"])
marks['Ananya']=85
marks["Kabir"]=75
max=0
for key,value in marks.items():
    if(value>max):
        max=value
        print(key,value)
print(marks)
# Out:
# 88
# Aarav 78
# Diya 92
# {'Aarav': 78, 'Diya': 92, 'Kabir': 75, 'Meera': 88, 'Rohan': 72, 'Ananya': 85}

# %%
n=int(input("Enter number of students: "))
marks={}
sum_marks={}
for key in range(0,n):
    name=input("Enter name of student: ")
    lst=[]
    total=0
    for i in range(5):
        sub_marks=int(input("Enter the marks: "))
        lst.append(sub_marks)
        total+=sub_marks
    marks[name]=lst
    sum_marks[name]=total
for key,value in sum_marks.items():
    if(sum>max):
        max=value
        print(key,value)
print(marks)
print(sum_marks)
# Out:
# {'Jatin': 466}
# {'Jatin': 466, 'Sumit': 460}
# Jatin 466
# {'Jatin': [98, 97, 90, 90, 91], 'Sumit': [90, 98, 94, 88, 90]}

# %%
n=int(input("Enter length of list: "))
lst=[]
for i in range(0,n):
    num=int(input("Enter the number:"))
    lst.append(num)
print(lst)
temp=0
max=0
for i in range(0,n):
    if(max<lst[i]):
        max=lst[i]
        temp=max
print(max)
print(temp)
# Out:
# [1, 2, 3]
# 3
# 3

# %%
lst=[10,3,2,0,-1]
target=9
def two_sum(arr,t):
    for i in range(0,5):
        a=arr[i]
        for j in range(0,i):
            sum=a+arr[j]
            if(sum==t):
                return a,arr[j]
result=two_sum(lst,target)
